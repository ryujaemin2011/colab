# %% [markdown]
# <a href="https://colab.research.google.com/github/ryujaemin2011/colab/blob/main/%EB%8B%B9%EB%87%A8%EB%B3%91_%EC%98%88%EC%B8%A1ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#라이브러리
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
import matplotlib.pyplot as plt

#데이터 가져오기
dataset = datasets.load_diabetes()

#데이터 타깃 준비
X,y = dataset['data'],dataset['target']

#분활
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=1)

#k-최근접 이웃 만들기
model = KNeighborsRegressor(n_neighbors=5)

#학습
model.fit(X_train,y_train)

#결정계수 계산
train_score = model.score(X_train,y_train)
test_score = model.score(X_test,y_test)

#출력
print(train_score)
print(test_score)

#다시 추론
y_predicted = model.predict(X_test)

#그래프
number_of_sample = 40
plt.plot(range(number_of_sample),y_test[:number_of_sample],label='real')
plt.plot(range(number_of_sample),y_predicted[:number_of_sample], label='predicted')
plt.ylabel('price')
plt.legend()
plt.show()
#아니 이거 정확도가
#이제 k-최근접 이웃 알고리즘은 버린다
# Out:
# 0.6054640983376878
# 0.28237175017432004
