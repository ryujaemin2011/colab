# %% [markdown]
# <a href="https://colab.research.google.com/github/ryujaemin2011/colab/blob/main/%EB%8B%B9%EB%87%A8%EB%B3%91_%EC%98%88%EC%B8%A1_%EB%A6%AC%EB%8B%88%EC%96%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#라이브러리
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
import matplotlib.pyplot as plt

#데이터 불러오기
dataset = datasets.load_diabetes()

#데이터,타깃 준비
X,y = dataset['data'],dataset['target']

#분활
X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=1)

#모델 만들기
model = Ridge(alpha=0)

#학습
model.fit(X_train,y_train)

#정확도 계산
train_score = model.score(X_train,y_train)
test_score = model.score(X_test,y_test)

#출력
print(train_score)
print(test_score)

#다시 추론
y_predicted = model.predict(X_test)

#그래프 그리기
number_of_sample = 40
plt.plot(range(number_of_sample),y_test[:number_of_sample], label='real')
plt.plot(range(number_of_sample),y_predicted[:number_of_sample], label='predicted')
plt.legend()
plt.show()

#계수 확인
print(model.coef_)

#y절편 확인
print(model.intercept_)
#이건 또 정확도가 왜이래
# Out:
# 0.5359163748137687
# 0.4439690125828356
# [  -7.85976574 -245.0498378   575.12383646  323.84954344 -519.78903584
#   250.62690777    0.96998187  180.50547491  614.76359069   52.10566318]
# 150.9977582372867
